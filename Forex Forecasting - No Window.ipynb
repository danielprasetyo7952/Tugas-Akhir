# %% [markdown]
# # Foreign Exchange Forecasting

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime, pytz

from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Constants

# %%
# Load data from Google Spreadsheet
SHEET_ID = '1JDNv_mArl-GPIpxuWS5GxgVEwvjXocS1MrXGc6TYs8M'
SHEET_NAME = ['USD/IDR', 'EUR/IDR', 'JPY/IDR']

# %% [markdown]
# ## Pre-Processing

# %%
url = f'https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv&sheet={SHEET_NAME[0]}'
data = pd.read_csv(url)

# Drop unused columns
data = data.drop('Unnamed: 2', axis=1)

# Convert Date columns to datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y %H:%M:%S')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1247 non-null   datetime64[ns]
#  1   Close   1247 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.6 KB

# %%
data.head()
# Out:
#                  Date     Close
# 0 2020-01-01 23:58:00  13689.23
# 1 2020-01-02 23:58:00  13884.79
# 2 2020-01-03 23:58:00  13935.46
# 3 2020-01-04 23:58:00  13935.46
# 4 2020-01-05 23:58:00  13934.32

# %%
data = data.groupby([pd.Grouper(key='Date', freq='D')]).first().reset_index()
data = data.set_index('Date')

# %%
split_date = '1-Jan-2023'
data_train = data.loc[data.index <= split_date].copy()
data_test = data.loc[data.index > split_date].copy()

# %%
training_set = data_train.values
training_set = np.reshape(training_set, (len(training_set), 1))

sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
X_train = training_set[0:len(training_set)-1]
y_train = training_set[1:len(training_set)]
X_train = np.reshape(X_train, (len(X_train), 1, 1))

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = data.plot(style='', figsize=(20,5), color=color_pal[0], title='USD/IDR by Days')

# %%
_ = data_test \
    .rename(columns={'Close': 'Test Set'}) \
    .join(data_train.rename(columns={'Close': 'Training Set'}), how='outer') \
    .plot(figsize=(20,5), title='USD/IDR by Days', style='')

# %% [markdown]
# ## Model Build

# %%
model = Sequential([
    LSTM(128, input_shape=(1, 1), return_sequences=True),
    LSTM(64, return_sequences=True),
    LSTM(32, return_sequences=False),
    Dense(1),
], name='LSTM')

model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['mae'])

model.summary()
# Out:
# 2023-06-11 22:14:18.922636: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:18.925460: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:18.926585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:19.061426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:19.062662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:19.063865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 1, 128)            66560
#
#  lstm_4 (LSTM)               (None, 1, 64)             49408
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 128,417
# Trainable params: 128,417
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-11 22:14:19.189885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:19.191546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:19.192831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=50,
                    validation_split=0.1)
# Out:
# Epoch 1/50
# 2023-06-11 22:14:19.460341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:19.461811: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:19.462860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:19.584341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:19.585443: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:19.586556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:19.712356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:19.714094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:19.715015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:20.637426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:20.639130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:20.640316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:20.750613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:20.751801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:20.752948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:20.866889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:20.868595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:20.869782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 28/31 [==========================>...] - ETA: 0s - loss: 0.1118 - mae: 0.3057
# 2023-06-11 22:14:22.871362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:22.872897: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:22.873854: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:22.976532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:22.977551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:22.978530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:23.083021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:23.084725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:23.085541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 31/31 [==============================] - 4s 30ms/step - loss: 0.1053 - mae: 0.2949 - val_loss: 0.1762 - val_mae: 0.4160
# Epoch 2/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0140 - mae: 0.0889 - val_loss: 0.0547 - val_mae: 0.2292
# Epoch 3/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0078 - mae: 0.0637 - val_loss: 0.0286 - val_mae: 0.1647
# Epoch 4/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0055 - mae: 0.0541 - val_loss: 0.0184 - val_mae: 0.1324
# Epoch 5/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0031 - mae: 0.0404 - val_loss: 0.0050 - val_mae: 0.0681
# Epoch 6/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0282 - val_loss: 0.0010 - val_mae: 0.0280
# Epoch 7/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0013 - mae: 0.0241 - val_loss: 8.3491e-04 - val_mae: 0.0237
# Epoch 8/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 0.0015 - val_mae: 0.0346
# Epoch 9/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - mae: 0.0241 - val_loss: 5.7801e-04 - val_mae: 0.0179
# Epoch 10/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 5.3159e-04 - val_mae: 0.0166
# Epoch 11/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - mae: 0.0230 - val_loss: 5.3486e-04 - val_mae: 0.0171
# Epoch 12/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 5.8458e-04 - val_mae: 0.0183
# Epoch 13/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - mae: 0.0232 - val_loss: 7.2795e-04 - val_mae: 0.0217
# Epoch 14/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - mae: 0.0226 - val_loss: 6.1168e-04 - val_mae: 0.0192
# Epoch 15/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0218 - val_loss: 5.3800e-04 - val_mae: 0.0171
# Epoch 16/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - mae: 0.0217 - val_loss: 4.8608e-04 - val_mae: 0.0160
# Epoch 17/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - mae: 0.0222 - val_loss: 4.8436e-04 - val_mae: 0.0158
# Epoch 18/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - mae: 0.0210 - val_loss: 6.6895e-04 - val_mae: 0.0208
# Epoch 19/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0218 - val_loss: 4.9581e-04 - val_mae: 0.0165
# Epoch 20/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0207 - val_loss: 5.3714e-04 - val_mae: 0.0177
# Epoch 21/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0207 - val_loss: 7.0281e-04 - val_mae: 0.0217
# Epoch 22/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0213 - val_loss: 6.5694e-04 - val_mae: 0.0208
# Epoch 23/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 4.8273e-04 - val_mae: 0.0165
# Epoch 24/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0204 - val_loss: 4.8830e-04 - val_mae: 0.0165
# Epoch 25/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0209 - val_loss: 4.6243e-04 - val_mae: 0.0160
# Epoch 26/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0200 - val_loss: 7.3868e-04 - val_mae: 0.0227
# Epoch 27/50
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0010 - mae: 0.0206 - val_loss: 4.6005e-04 - val_mae: 0.0159
# Epoch 28/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0208 - val_loss: 8.0056e-04 - val_mae: 0.0226
# Epoch 29/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0216 - val_loss: 4.6703e-04 - val_mae: 0.0164
# Epoch 30/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0207 - val_loss: 4.2169e-04 - val_mae: 0.0148
# Epoch 31/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0198 - val_loss: 6.4584e-04 - val_mae: 0.0208
# Epoch 32/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0217 - val_loss: 4.2870e-04 - val_mae: 0.0152
# Epoch 33/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0205 - val_loss: 7.1639e-04 - val_mae: 0.0223
# Epoch 34/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0220 - val_loss: 7.7855e-04 - val_mae: 0.0235
# Epoch 35/50
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0011 - mae: 0.0213 - val_loss: 3.9879e-04 - val_mae: 0.0141
# Epoch 36/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0200 - val_loss: 4.4235e-04 - val_mae: 0.0158
# Epoch 37/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0197 - val_loss: 4.0082e-04 - val_mae: 0.0140
# Epoch 38/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0199 - val_loss: 6.4645e-04 - val_mae: 0.0209
# Epoch 39/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0010 - mae: 0.0201 - val_loss: 4.9897e-04 - val_mae: 0.0174
# Epoch 40/50
# 31/31 [==============================] - 0s 9ms/step - loss: 9.9904e-04 - mae: 0.0196 - val_loss: 5.0464e-04 - val_mae: 0.0177
# Epoch 41/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0212 - val_loss: 9.2234e-04 - val_mae: 0.0262
# Epoch 42/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0011 - mae: 0.0211 - val_loss: 4.5117e-04 - val_mae: 0.0160
# Epoch 43/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0010 - mae: 0.0201 - val_loss: 4.3479e-04 - val_mae: 0.0157
# Epoch 44/50
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0010 - mae: 0.0205 - val_loss: 4.5533e-04 - val_mae: 0.0163
# Epoch 45/50
# 31/31 [==============================] - 0s 10ms/step - loss: 9.9724e-04 - mae: 0.0198 - val_loss: 5.1564e-04 - val_mae: 0.0179
# Epoch 46/50
# 31/31 [==============================] - 0s 10ms/step - loss: 9.9204e-04 - mae: 0.0195 - val_loss: 4.6960e-04 - val_mae: 0.0164
# Epoch 47/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0011 - mae: 0.0215 - val_loss: 4.0388e-04 - val_mae: 0.0140
# Epoch 48/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0209 - val_loss: 6.2096e-04 - val_mae: 0.0203
# Epoch 49/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0202 - val_loss: 5.2869e-04 - val_mae: 0.0178
# Epoch 50/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0202 - val_loss: 4.1615e-04 - val_mae: 0.0149

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ## Predictions

# %%
# Making the predictions
test_set = data_test.values
inputs = np.reshape(test_set, (len(test_set), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
predicted_USD_price = model.predict(inputs)
predicted_USD_price = sc.inverse_transform(predicted_USD_price)
# Out:
# 2023-06-11 22:14:39.714428: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:39.716087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:39.717058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-11 22:14:39.827696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:39.828793: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:39.830099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 5/5 [==============================] - 1s 6ms/step
# 2023-06-11 22:14:39.949835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-11 22:14:39.951289: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-11 22:14:39.952333: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
data_test['Close_Price_Prediction'] = predicted_USD_price
data_all = pd.concat([data_test, data_train], sort=False)

# %%
#saving the predicted values in a common data frame for future comparision
final_data = data_all
final_data = final_data.reset_index()
final_data = final_data.rename(columns={'Close_Price_Prediction': 'lstm'})
final_data = final_data[['Date','Close','lstm']]

# %%
_ = data_all[['Close','Close_Price_Prediction']].plot(figsize=(15, 5))

# %%
# Plot the forecast with the actuals
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = data_all[['Close_Price_Prediction','Close']].plot(ax=ax,
                                              style=['--','-'])
ax.set_xbound(lower='01-01-2023', upper='06-01-2023')
plot = plt.suptitle('January 2023 Forecast vs Actuals')

# %%
def matrices(actual, predicted):
    mse = mean_squared_error(actual, predicted)
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mse)
    print("Mean Squared Error for prediction :", mse)
    print("Mean Absolute Error for prediction :", mae)
    print("Root Mean Squared Error for prediction :", rmse)
    
matrices(data_test['Close'], data_test['Close_Price_Prediction'])
# Out:
# Mean Squared Error for prediction : 36.54257304789146
# Mean Absolute Error for prediction : 5.048679687499983
# Root Mean Squared Error for prediction : 6.045045330507577
